# %% [markdown]
# ## Step 1: Create a SparkSession with a SparkContext

# %%
import pyspark
spark = pyspark.sql.SparkSession.builder.getOrCreate()
sc = spark.sparkContext

# %%
spark
# Out:
#             <div>
#                 <p><b>SparkSession - in-memory</b></p>
#
#         <div>
#             <p><b>SparkContext</b></p>
#
#             <p><a href="http://10.137.1.145:4040">Spark UI</a></p>
#
#             <dl>
#               <dt>Version</dt>
#                 <dd><code>v2.4.3</code></dd>
#               <dt>Master</dt>
#                 <dd><code>local[*]</code></dd>
#               <dt>AppName</dt>
#                 <dd><code>pyspark-shell</code></dd>
#             </dl>
#         </div>
#
#             </div>

# %%
sc
# Out:
# <SparkContext master=local[*] appName=pyspark-shell>

# %% [markdown]
# ## Step 2: Create a Spark DataFrame

# %%
import pandas as pd

# %% [markdown]
# ### Ratings Dataframe

# %%
#Notice this is a local file. There are computer clusters don't have local files so be careful.
rf = spark.read.json('data/ratings.json')

# %%
#look at schema
rf
# Out:
# DataFrame[movie_id: bigint, rating: bigint, timestamp: double, user_id: bigint]

# %%
rf.limit(5).show()
# Out:
# +--------+------+------------+-------+
# |movie_id|rating|   timestamp|user_id|
# +--------+------+------------+-------+
# |     858|     4|9.56678732E8|   6040|
# |    2384|     4|9.56678754E8|   6040|
# |     593|     5|9.56678754E8|   6040|
# |    1961|     4|9.56678777E8|   6040|
# |    1419|     3|9.56678856E8|   6040|
# +--------+------+------------+-------+

# %%
rf.limit(5).toPandas()
# Out:
#    movie_id  rating    timestamp  user_id
# 0       858       4  956678732.0     6040
# 1      2384       4  956678754.0     6040
# 2       593       5  956678754.0     6040
# 3      1961       4  956678777.0     6040
# 4      1419       3  956678856.0     6040

# %%
#Instead of loading this file in over again every time we want to look at it, we'll use
rf.persist()
# Out:
# DataFrame[movie_id: bigint, rating: bigint, timestamp: double, user_id: bigint]

# %%
rf.head()
# Out:
# Row(movie_id=858, rating=4, timestamp=956678732.0, user_id=6040)

# %%
drf = rf.toPandas()

# %%
drf.head()
# Out:
#    movie_id  rating    timestamp  user_id
# 0       858       4  956678732.0     6040
# 1      2384       4  956678754.0     6040
# 2       593       5  956678754.0     6040
# 3      1961       4  956678777.0     6040
# 4      1419       3  956678856.0     6040

# %%
drf.movie_id.value_counts()
# Out:
# 2858    2619
# 260     2258
# 1196    2244
# 1210    2204
# 589     2069
# 480     2025
# 2028    2003
# 1270    1993
# 608     1942
# 2571    1937
# 1580    1931
# 593     1917
# 1198    1900
# 110     1877
# 2762    1839
# 2396    1819
# 1197    1765
# 527     1754
# 1617    1734
# 1097    1725
# 2628    1722
# 2997    1706
# 858     1688
# 1265    1680
# 318     1670
# 2716    1639
# 356     1631
# 296     1626
# 1240    1586
# 1       1559
#         ...
# 3295       1
# 3601       1
# 2510       1
# 3290       1
# 730        1
# 1470       1
# 758        1
# 1558       1
# 1118       1
# 2845       1
# 796        1
# 3353       1
# 601        1
# 792        1
# 790        1
# 1115       1
# 789        1
# 3164       1
# 1630       1
# 3607       1
# 607        1
# 3337       1
# 98         1
# 2484       1
# 2308       1
# 2584       1
# 3842       1
# 3687       1
# 2811       1
# 3890       1
# Name: movie_id, Length: 3642, dtype: int64

# %% [markdown]
# It looks like we have ratings for 3642 movies.

# %%
drf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 719949 entries, 0 to 719948
# Data columns (total 4 columns):
# movie_id     719949 non-null int64
# rating       719949 non-null int64
# timestamp    719949 non-null float64
# user_id      719949 non-null int64
# dtypes: float64(1), int64(3)
# memory usage: 22.0 MB

# %%
drf.user_id.value_counts()
# Out:
# 1680    1671
# 889     1384
# 4169    1300
# 4277    1255
# 3618    1198
# 1941    1183
# 1150    1175
# 5795    1159
# 4344    1145
# 4510    1114
# 4227    1091
# 3841    1083
# 4508    1054
# 3808    1048
# 5367    1006
# 3539     971
# 2063     963
# 5831     947
# 3224     923
# 4725     914
# 5643     913
# 3032     910
# 4064     898
# 2909     894
# 5954     887
# 1285     886
# 4447     878
# 1181     875
# 1980     871
# 3778     866
#         ...
# 1447       5
# 5484       5
# 5998       5
# 1547       5
# 4610       5
# 2775       5
# 1463       5
# 5291       5
# 918        5
# 3991       5
# 4418       5
# 4744       5
# 750        5
# 2057       5
# 4467       5
# 1252       5
# 3152       4
# 1779       4
# 4528       4
# 4463       4
# 827        4
# 2991       4
# 988        4
# 1256       3
# 3288       3
# 1551       3
# 4273       3
# 3038       2
# 3326       1
# 3459       1
# Name: user_id, Length: 5400, dtype: int64

# %% [markdown]
# It looks like we 5400 unique users.

# %% [markdown]
# ### Requests Dataframe. This is the Dataframe of movies users have not seen, which we will populate with recommendations.

# %%
#Notice this is a local file. There are computer clusters don't have local files so be careful.
rq = spark.read.json('data/requests.json')

# %%
#look at schema
rq
# Out:
# DataFrame[movie_id: bigint, rating: double, timestamp: double, user_id: bigint]

# %%
rq.limit(5).show()
# Out:
# +--------+------+------------+-------+
# |movie_id|rating|   timestamp|user_id|
# +--------+------+------------+-------+
# |    2019|   NaN|9.56678777E8|   6040|
# |     759|   NaN|9.56679248E8|   6040|
# |    2858|   NaN|9.56679275E8|   6040|
# |     246|   NaN|9.56679413E8|   6040|
# |    1617|   NaN|9.56679473E8|   6040|
# +--------+------+------------+-------+

# %%
rq.limit(5).toPandas()
# Out:
#    movie_id  rating    timestamp  user_id
# 0      2019     NaN  956678777.0     6040
# 1       759     NaN  956679248.0     6040
# 2      2858     NaN  956679275.0     6040
# 3       246     NaN  956679413.0     6040
# 4      1617     NaN  956679473.0     6040

# %%
#Instead of loading this file in over again every time we want to look at it, we'll use
rq.persist()
# Out:
# DataFrame[movie_id: bigint, rating: double, timestamp: double, user_id: bigint]

# %%
rq.head()
# Out:
# Row(movie_id=2019, rating=nan, timestamp=956678777.0, user_id=6040)

# %%
drq = rq.toPandas()

# %%
drq.head()
# Out:
#    movie_id  rating    timestamp  user_id
# 0      2019     NaN  956678777.0     6040
# 1       759     NaN  956679248.0     6040
# 2      2858     NaN  956679275.0     6040
# 3       246     NaN  956679413.0     6040
# 4      1617     NaN  956679473.0     6040

# %%
drq.loc[drq.user_id == 2019]
# Out:
#         movie_id  rating    timestamp  user_id
# 59543       2858     NaN  974644829.0     2019
# 59561        233     NaN  974645173.0     2019
# 59567       2716     NaN  974645272.0     2019
# 59577       2622     NaN  974645688.0     2019
# 211269      3155     NaN  983443459.0     2019
# 211270      3751     NaN  983443528.0     2019
# 211271      3863     NaN  983443528.0     2019
# 211272      3578     NaN  983443583.0     2019

# %%
drq.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 280260 entries, 0 to 280259
# Data columns (total 4 columns):
# movie_id     280260 non-null int64
# rating       0 non-null float64
# timestamp    280260 non-null float64
# user_id      280260 non-null int64
# dtypes: float64(2), int64(2)
# memory usage: 8.6 MB

# %%
drq.movie_id.value_counts()
# Out:
# 2858    809
# 3578    759
# 1196    746
# 260     733
# 1210    679
# 593     661
# 2571    653
# 2028    650
# 480     647
# 2762    620
# 1198    614
# 1580    607
# 1265    598
# 1270    590
# 589     580
# 3751    577
# 608     571
# 110     566
# 356     563
# 318     557
# 1617    554
# 1197    553
# 2396    550
# 527     550
# 296     545
# 1097    544
# 2716    542
# 3793    540
# 858     535
# 2997    535
#        ...
# 1324      1
# 865       1
# 775       1
# 744       1
# 3542      1
# 981       1
# 980       1
# 1908      1
# 1039      1
# 33        1
# 3209      1
# 1160      1
# 2592      1
# 712       1
# 3460      1
# 1154      1
# 3533      1
# 717       1
# 2850      1
# 2172      1
# 1316      1
# 634       1
# 1145      1
# 889       1
# 120       1
# 3280      1
# 2343      1
# 887       1
# 2258      1
# 402       1
# Name: movie_id, Length: 3564, dtype: int64

# %% [markdown]
# It looks like we have 3540 unique movies.

# %%
drq.user_id.value_counts()
# Out:
# 424     1226
# 549     1152
# 1088    1074
# 1448    1025
# 524     1016
# 4169    1014
# 1447     985
# 550      967
# 678      945
# 352      870
# 531      867
# 482      825
# 195      822
# 216      794
# 302      788
# 1733     777
# 329      764
# 245      764
# 1912     746
# 509      723
# 319      721
# 5394     697
# 53       684
# 543      671
# 202      670
# 1181     646
# 1425     644
# 411      635
# 1266     633
# 148      624
#         ...
# 1126       1
# 3897       1
# 1089       1
# 2081       1
# 3282       1
# 4264       1
# 1801       1
# 3541       1
# 2260       1
# 2516       1
# 1237       1
# 4941       1
# 4672       1
# 3446       1
# 835        1
# 1911       1
# 2568       1
# 799        1
# 5589       1
# 5206       1
# 2007       1
# 5898       1
# 1703       1
# 4570       1
# 867        1
# 2470       1
# 5796       1
# 986        1
# 5336       1
# 4652       1
# Name: user_id, Length: 5970, dtype: int64

# %% [markdown]
# It looks like we have 5970 users to whom we want to recommend movies.

# %% [markdown]
# ## Read users.data and movies.data into dataframes

# %%
usdf = pd.read_csv('data/users.dat', sep='::', header=None)
# Out:
# /anaconda3/envs/learn-env/lib/python3.6/site-packages/ipykernel_launcher.py:1: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.
#   """Entry point for launching an IPython kernel.

# %%
usdf.head()
# Out:
#    0  1   2   3      4
# 0  1  F   1  10  48067
# 1  2  M  56  16  70072
# 2  3  M  25  15  55117
# 3  4  M  45   7  02460
# 4  5  M  25  20  55455

# %%
mvdf_headers = ['title', 'genres']

# %%
mvdf = pd.read_csv('data/movies.dat', sep='::', names=mvdf_headers, index_col=0)
# Out:
# /anaconda3/envs/learn-env/lib/python3.6/site-packages/ipykernel_launcher.py:1: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.
#   """Entry point for launching an IPython kernel.

# %%
mvdf.head()
# Out:
#                                 title                        genres
# 1                    Toy Story (1995)   Animation|Children's|Comedy
# 2                      Jumanji (1995)  Adventure|Children's|Fantasy
# 3             Grumpier Old Men (1995)                Comedy|Romance
# 4            Waiting to Exhale (1995)                  Comedy|Drama
# 5  Father of the Bride Part II (1995)                        Comedy

# %%
mvdf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3883 entries, 1 to 3952
# Data columns (total 2 columns):
# title     3883 non-null object
# genres    3883 non-null object
# dtypes: object(2)
# memory usage: 91.0+ KB

# %%
# mvdf.genres.str.split('|', expand=True)
# Out:
#               0           1           2     3     4     5
# 1     Animation  Children's      Comedy  None  None  None
# 2     Adventure  Children's     Fantasy  None  None  None
# 3        Comedy     Romance        None  None  None  None
# 4        Comedy       Drama        None  None  None  None
# 5        Comedy        None        None  None  None  None
# 6        Action       Crime    Thriller  None  None  None
# 7        Comedy     Romance        None  None  None  None
# 8     Adventure  Children's        None  None  None  None
# 9        Action        None        None  None  None  None
# 10       Action   Adventure    Thriller  None  None  None
# 11       Comedy       Drama     Romance  None  None  None
# 12       Comedy      Horror        None  None  None  None
# 13    Animation  Children's        None  None  None  None
# 14        Drama        None        None  None  None  None
# 15       Action   Adventure     Romance  None  None  None
# 16        Drama    Thriller        None  None  None  None
# 17        Drama     Romance        None  None  None  None
# 18     Thriller        None        None  None  None  None
# 19       Comedy        None        None  None  None  None
# 20       Action        None        None  None  None  None
# 21       Action      Comedy       Drama  None  None  None
# 22        Crime       Drama    Thriller  None  None  None
# 23     Thriller        None        None  None  None  None
# 24        Drama      Sci-Fi        None  None  None  None
# 25        Drama     Romance        None  None  None  None
# 26        Drama        None        None  None  None  None
# 27        Drama        None        None  None  None  None
# 28      Romance        None        None  None  None  None
# 29    Adventure      Sci-Fi        None  None  None  None
# 30        Drama        None        None  None  None  None
# ...         ...         ...         ...   ...   ...   ...
# 3923     Horror      Sci-Fi        None  None  None  None
# 3924     Comedy        None        None  None  None  None
# 3925     Comedy        None        None  None  None  None
# 3926  Adventure      Sci-Fi        None  None  None  None
# 3927  Adventure      Sci-Fi        None  None  None  None
# 3928     Comedy      Horror        None  None  None  None
# 3929     Comedy        None        None  None  None  None
# 3930     Horror        None        None  None  None  None
# 3931     Horror      Sci-Fi        None  None  None  None
# 3932     Horror      Sci-Fi        None  None  None  None
# 3933     Horror      Sci-Fi        None  None  None  None
# 3934     Sci-Fi        None        None  None  None  None
# 3935     Horror        None        None  None  None  None
# 3936      Drama    Thriller        None  None  None  None
# 3937     Sci-Fi    Thriller        None  None  None  None
# 3938     Horror        None        None  None  None  None
# 3939     Horror        None        None  None  None  None
# 3940     Horror        None        None  None  None  None
# 3941     Horror        None        None  None  None  None
# 3942     Horror        None        None  None  None  None
# 3943     Comedy        None        None  None  None  None
# 3944     Comedy       Drama        None  None  None  None
# 3945  Adventure   Animation  Children's  None  None  None
# 3946     Action       Drama    Thriller  None  None  None
# 3947   Thriller        None        None  None  None  None
# 3948     Comedy        None        None  None  None  None
# 3949      Drama        None        None  None  None  None
# 3950      Drama        None        None  None  None  None
# 3951      Drama        None        None  None  None  None
# 3952      Drama    Thriller        None  None  None  None
#
# [3883 rows x 6 columns]

# %%
metadf = pd.read_csv('data/movies_metadata.csv')
# Out:
# /anaconda3/envs/learn-env/lib/python3.6/site-packages/IPython/core/interactiveshell.py:2785: DtypeWarning: Columns (10) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
metadf.head()
# Out:
#    adult                              belongs_to_collection    budget  \
# 0  False  {'id': 10194, 'name': 'Toy Story Collection', ...  30000000
# 1  False                                                NaN  65000000
# 2  False  {'id': 119050, 'name': 'Grumpy Old Men Collect...         0
# 3  False                                                NaN  16000000
# 4  False  {'id': 96871, 'name': 'Father of the Bride Col...         0
#
#                                               genres  \
# 0  [{'id': 16, 'name': 'Animation'}, {'id': 35, '...
# 1  [{'id': 12, 'name': 'Adventure'}, {'id': 14, '...
# 2  [{'id': 10749, 'name': 'Romance'}, {'id': 35, ...
# 3  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# 4                     [{'id': 35, 'name': 'Comedy'}]
#
#                                homepage     id    imdb_id original_language  \
# 0  http://toystory.disney.com/toy-story    862  tt0114709                en
# 1                                   NaN   8844  tt0113497                en
# 2                                   NaN  15602  tt0113228                en
# 3                                   NaN  31357  tt0114885                en
# 4                                   NaN  11862  tt0113041                en
#
#                 original_title  \
# 0                    Toy Story
# 1                      Jumanji
# 2             Grumpier Old Men
# 3            Waiting to Exhale
# 4  Father of the Bride Part II
#
#                                             overview    ...     release_date  \
# 0  Led by Woody, Andy's toys live happily in his ...    ...       1995-10-30
# 1  When siblings Judy and Peter discover an encha...    ...       1995-12-15
# 2  A family wedding reignites the ancient feud be...    ...       1995-12-22
# 3  Cheated on, mistreated and stepped on, the wom...    ...       1995-12-22
# 4  Just when George Banks has recovered from his ...    ...       1995-02-10
#
#        revenue runtime                                   spoken_languages  \
# 0  373554033.0    81.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 1  262797249.0   104.0  [{'iso_639_1': 'en', 'name': 'English'}, {'iso...
# 2          0.0   101.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 3   81452156.0   127.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 4   76578911.0   106.0           [{'iso_639_1': 'en', 'name': 'English'}]
#
#      status                                            tagline  \
# 0  Released                                                NaN
# 1  Released          Roll the dice and unleash the excitement!
# 2  Released  Still Yelling. Still Fighting. Still Ready for...
# 3  Released  Friends are the people who let you be yourself...
# 4  Released  Just When His World Is Back To Normal... He's ...
#
#                          title  video vote_average vote_count
# 0                    Toy Story  False          7.7     5415.0
# 1                      Jumanji  False          6.9     2413.0
# 2             Grumpier Old Men  False          6.5       92.0
# 3            Waiting to Exhale  False          6.1       34.0
# 4  Father of the Bride Part II  False          5.7      173.0
#
# [5 rows x 24 columns]

# %%
#df['Capital'] = df['Country'].map(country_capital)
metadf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45466 entries, 0 to 45465
# Data columns (total 24 columns):
# adult                    45466 non-null object
# belongs_to_collection    4494 non-null object
# budget                   45466 non-null object
# genres                   45466 non-null object
# homepage                 7782 non-null object
# id                       45466 non-null object
# imdb_id                  45449 non-null object
# original_language        45455 non-null object
# original_title           45466 non-null object
# overview                 44512 non-null object
# popularity               45461 non-null object
# poster_path              45080 non-null object
# production_companies     45463 non-null object
# production_countries     45463 non-null object
# release_date             45379 non-null object
# revenue                  45460 non-null float64
# runtime                  45203 non-null float64
# spoken_languages         45460 non-null object
# status                   45379 non-null object
# tagline                  20412 non-null object
# title                    45460 non-null object
# video                    45460 non-null object
# vote_average             45460 non-null float64
# vote_count               45460 non-null float64
# dtypes: float64(4), object(20)
# memory usage: 8.3+ MB

# %%
print(metadf.genres[1])
print(type(metadf.genres[1]))
# Out:
# [{'id': 12, 'name': 'Adventure'}, {'id': 14, 'name': 'Fantasy'}, {'id': 10751, 'name': 'Family'}]
# <class 'str'>

# %%
import json

# %%
json.loads(metadf.genres[0])
# Out:
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# <ipython-input-46-2bfac616fff3> in <module>()
# ----> 1 json.loads(metadf.genres[0])
#
# /anaconda3/envs/learn-env/lib/python3.6/json/__init__.py in loads(s, encoding, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     352             parse_int is None and parse_float is None and
#     353             parse_constant is None and object_pairs_hook is None and not kw):
# --> 354         return _default_decoder.decode(s)
#     355     if cls is None:
#     356         cls = JSONDecoder
#
# /anaconda3/envs/learn-env/lib/python3.6/json/decoder.py in decode(self, s, _w)
#     337
#     338         """
# --> 339         obj, end = self.raw_decode(s, idx=_w(s, 0).end())
#     340         end = _w(s, end).end()
#     341         if end != len(s):
#
# /anaconda3/envs/learn-env/lib/python3.6/json/decoder.py in raw_decode(self, s, idx)
#     353         """
#     354         try:
# --> 355             obj, end = self.scan_once(s, idx)
#     356         except StopIteration as err:
#     357             raise JSONDecodeError("Expecting value", s, err.value) from None
#
# JSONDecodeError: Expecting property name enclosed in double quotes: line 1 column 3 (char 2)

# %%
pd.merge(mvdf, metadf, how='left', left_on='')
